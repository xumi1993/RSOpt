# %%
import matplotlib.pyplot as plt
import h5py
import pandas as pd

# %%
with h5py.File('./OUTPUT_FILES/final_model.h5', 'r') as f:
    print(f.keys())
    vs = f['vs'][:]
    dep = f['depth'][:]
# Out:
# <KeysViewHDF5 ['depth', 'vs']>

# %%
plt.figure(figsize=(3,6))
plt.step(vs, dep, where='post')
plt.gca().invert_yaxis()

# %%
# read data
df_dat = pd.read_csv('disp.dat', sep='\s+', header=None)
# read syn
df_syn = pd.read_csv('./OUTPUT_FILES/syn_surf_045.dat', sep='\s+', header=None)

# %%
# plot data
plt.plot(df_dat[0], df_dat[1], 'ro', label='data')
# plot syn
plt.plot(df_syn[0], df_syn[1], 'bo', label='syn')
